# %%
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/diabetes-in-youth-vs-adult-in-india/diabetes_young_adults_india.csv")

# %%
df.head()
# Out:
#    ID  Age  Gender     Region  Family_Income Family_History_Diabetes  \
# 0   1   21    Male      North        2209393                      No
# 1   2   18  Female    Central         387650                      No
# 2   3   25    Male      North         383333                      No
# 3   4   22    Male  Northeast        2443733                      No
# 4   5   19    Male    Central        1449463                      No
#
#   Parent_Diabetes_Type  Genetic_Risk_Score   BMI Physical_Activity_Level  ...  \
# 0                  NaN                   6  31.4               Sedentary  ...
# 1                  NaN                   5  24.4                  Active  ...
# 2                  NaN                   6  20.0                Moderate  ...
# 3                  NaN                   4  39.8                Moderate  ...
# 4                  NaN                   4  19.2                Moderate  ...
#
#   Smoking  Alcohol_Consumption Fasting_Blood_Sugar HbA1c  Cholesterol_Level  \
# ...

# %%
result = df[(df["Age"] <= 19) & (df["Age"]>=15) & (df["Diabetes_Type"] == "Type 1")]
print(result.loc[:, ["Age", "Diabetes_Type"]])
# Out:
#        Age Diabetes_Type
# 19      16        Type 1
# 55      17        Type 1
# 69      16        Type 1
# 113     17        Type 1
# 145     16        Type 1
# ...    ...           ...
# 99663   17        Type 1
# 99681   18        Type 1
# 99712   16        Type 1
# 99849   19        Type 1
# 99999   18        Type 1
#
# [2165 rows x 2 columns]

# %%
result2 = df[
    (df["Gender"] == "Female") & 
    (df["Age"] >= 15) & 
    (df["Age"] <= 19) & 
    ((df["Diabetes_Type"] == "Type 1") | (df["Diabetes_Type"] == "Type 2"))
]

# Print the selected columns
print(result2.loc[:, ["Gender", "Age", "Diabetes_Type"]])
# Out:
#        Gender  Age Diabetes_Type
# 19     Female   16        Type 1
# 28     Female   15        Type 2
# 37     Female   19        Type 2
# 52     Female   18        Type 2
# 55     Female   17        Type 1
# ...       ...  ...           ...
# 99923  Female   19        Type 2
# 99970  Female   15        Type 2
# 99973  Female   17        Type 2
# 99995  Female   19        Type 2
# 99999  Female   18        Type 1
#
# [5515 rows x 3 columns]

# %%
df.isnull()
# Out:
#           ID    Age  Gender  Region  Family_Income  Family_History_Diabetes  \
# 0      False  False   False   False          False                    False
# 1      False  False   False   False          False                    False
# 2      False  False   False   False          False                    False
# 3      False  False   False   False          False                    False
# 4      False  False   False   False          False                    False
# ...      ...    ...     ...     ...            ...                      ...
# 99995  False  False   False   False          False                    False
# 99996  False  False   False   False          False                    False
# 99997  False  False   False   False          False                    False
# 99998  False  False   False   False          False                    False
# 99999  False  False   False   False          False                    False
#
# ...

# %%
df.isnull().sum()
# Out:
# ID                             0
# Age                            0
# Gender                         0
# Region                         0
# Family_Income                  0
# Family_History_Diabetes        0
# Parent_Diabetes_Type       65097
# Genetic_Risk_Score             0
# BMI                            0
# Physical_Activity_Level        0
# Dietary_Habits                 0
# Fast_Food_Intake               0
# Smoking                        0
# Alcohol_Consumption            0
# Fasting_Blood_Sugar            0
# HbA1c                          0
# Cholesterol_Level              0
# Prediabetes                    0
# Diabetes_Type              74776
# Sleep_Hours                    0
# Stress_Level                   0
# Screen_Time                    0
# dtype: int64

# %%
df["Prone to depression"] = df["Diabetes_Type"].apply(lambda x: "Not Prone" if pd.isnull(x) else "Prone")

# %%
df.iloc[22:33]
# Out:
#     ID  Age  Gender   Region  Family_Income Family_History_Diabetes  \
# 22  23   16  Female     East        2424828                     Yes
# 23  24   19   Other  Central        1561481                      No
# 24  25   15    Male     West        2106250                      No
# 25  26   24  Female    South         867801                      No
# 26  27   20    Male     West         159841                      No
# 27  28   23  Female     West         286725                      No
# 28  29   15  Female     West        1781800                     Yes
# 29  30   25    Male    South         422446                     Yes
# 30  31   25    Male    North        1598840                      No
# 31  32   24  Female    North        1657317                     Yes
# 32  33   17    Male     East        1833943                      No
#
#    Parent_Diabetes_Type  Genetic_Risk_Score   BMI Physical_Activity_Level  \
# 22                  NaN                  10  26.2               Sedentary
# ...
